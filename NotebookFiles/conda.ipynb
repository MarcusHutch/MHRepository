# %%
import pandas as pd
df = pd.read_csv("https://github.com/MarcusHutch/MHRepository_Public/raw/main/PatientSample.csv")
display(df)
# Out:
#       Number First_Name   Last_Name                   Company_Name  \
# 0   10123456    Aleshia  Tomkiewicz        Alan D Rosenburg Cpa Pc
# 1   10123457       Evan   Zigomalas             Cap Gemini America
# 2   10123458     France     Andrade             Elliott John W Esq
# 3   10123459    Ulysses   Mcwalters                  Mcmahan Ben L
# 4   10123460     Tyisha      Veness                 Champagne Room
# 5   10123461       Eric       Rampy         Thompson Michael C Esq
# 6   10123462       Marg    Grasmick  Wrangle Hill Auto Auct & Slvg
# 7   10123463    Laquita       Hisaw          In Communications Inc
# 8   10123464       Lura    Manzella                Bizerba Usa Inc
# 9   10123505       Test     Testing                   Test Company
# 10  10123507      Test1    Testing1                  Test Company1
#
#                  Address                            City  \
# 0           14 Taylor St               St. Stephens Ward
# ...
